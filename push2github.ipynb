# %% [markdown]
# ## 0， pip list

# %%
#!pip install numpy -i  https://pypi.tuna.tsinghua.edu.cn/simple    
#!pip install pandas -i  https://pypi.tuna.tsinghua.edu.cn/simple    
#!pip install torch -i  https://pypi.tuna.tsinghua.edu.cn/simple     
#!pip install accelerate -i  https://pypi.tuna.tsinghua.edu.cn/simple   
#!pip install matplotlib -i  https://pypi.tuna.tsinghua.edu.cn/simple  
#!pip install torchvision  -i  https://pypi.tuna.tsinghua.edu.cn/simple  
#!pip install omegaconf  -i  https://pypi.tuna.tsinghua.edu.cn/simple   
#!pip install einops  -i  https://pypi.tuna.tsinghua.edu.cn/simple   
#!pip install scikit-learn -i  https://pypi.tuna.tsinghua.edu.cn/simple  
#!pip install ipywidgets -i  https://pypi.tuna.tsinghua.edu.cn/simple  
#!pip install pyarrow -i  https://pypi.tuna.tsinghua.edu.cn/simple  
#!pip install seaborn -i  https://pypi.tuna.tsinghua.edu.cn/simple  
#!pip install lightgbm -i  https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ## 1, Upload to  Pypi

# %%
#!uv build

# %%
#!uv publish

# %%
# %run setup.py sdist bdist_wheel
# Out:
# running sdist
# running egg_info
# creating torchkeras.egg-info
# writing torchkeras.egg-info/PKG-INFO
# writing dependency_links to torchkeras.egg-info/dependency_links.txt
# writing top-level names to torchkeras.egg-info/top_level.txt
# writing manifest file 'torchkeras.egg-info/SOURCES.txt'
# /Users/admin/miniforge3/lib/python3.12/site-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
# !!
#
#         ********************************************************************************
#         Please consider removing the following classifiers in favor of a SPDX license expression:
#
#         License :: OSI Approved :: MIT License
#
#         See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#         ********************************************************************************
#
# !!
#   self._finalize_license_expression()
# reading manifest file 'torchkeras.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'torchkeras/*.ttf'
# no previously-included directories found matching 'torchkeras/assets/*checkpoint*'
# warning: no files found matching '*.png' under directory 'torchkeras/assets'
# warning: no files found matching '*.jpeg' under directory 'torchkeras/assets'
# warning: no previously-included files matching '*' found under directory 'torchkeras/__pycache__'
# warning: no previously-included files matching '*' found under directory 'torchkeras/.ipynb_checkpoints'
# adding license file 'LICENSE'
# writing manifest file 'torchkeras.egg-info/SOURCES.txt'
# running check
# creating torchkeras-4.0.5
# creating torchkeras-4.0.5/torchkeras
# creating torchkeras-4.0.5/torchkeras.egg-info
# creating torchkeras-4.0.5/torchkeras/assets
# creating torchkeras-4.0.5/torchkeras/chat
# creating torchkeras-4.0.5/torchkeras/tabular
# creating torchkeras-4.0.5/torchkeras/tabular/config
# creating torchkeras-4.0.5/torchkeras/tabular/models
# creating torchkeras-4.0.5/torchkeras/tabular/models/autoint
# creating torchkeras-4.0.5/torchkeras/tabular/models/category_embedding
# creating torchkeras-4.0.5/torchkeras/tabular/models/common
# creating torchkeras-4.0.5/torchkeras/tabular/models/common/heads
# creating torchkeras-4.0.5/torchkeras/tabular/models/common/layers
# creating torchkeras-4.0.5/torchkeras/tabular/models/danet
# creating torchkeras-4.0.5/torchkeras/tabular/models/deepcross
# creating torchkeras-4.0.5/torchkeras/tabular/models/deepfm
# creating torchkeras-4.0.5/torchkeras/tabular/models/deepknn
# creating torchkeras-4.0.5/torchkeras/tabular/models/fm
# creating torchkeras-4.0.5/torchkeras/tabular/models/ft_transformer
# creating torchkeras-4.0.5/torchkeras/tabular/models/gandalf
# creating torchkeras-4.0.5/torchkeras/tabular/models/gate
# creating torchkeras-4.0.5/torchkeras/tabular/models/node
# creating torchkeras-4.0.5/torchkeras/tabular/models/pemlp
# creating torchkeras-4.0.5/torchkeras/tabular/models/tab_transformer
# creating torchkeras-4.0.5/torchkeras/tabular/models/tabm
# creating torchkeras-4.0.5/torchkeras/tabular/models/tabnet
# creating torchkeras-4.0.5/torchkeras/tabular/utils
# creating torchkeras-4.0.5/torchkeras/tools
# creating torchkeras-4.0.5/torchkeras/vision
# copying files to torchkeras-4.0.5...
# copying LICENSE -> torchkeras-4.0.5
# copying MANIFEST.in -> torchkeras-4.0.5
# copying README.md -> torchkeras-4.0.5
# copying pyproject.toml -> torchkeras-4.0.5
# copying setup.py -> torchkeras-4.0.5
# copying torchkeras/__init__.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/data.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/eda.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/email.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/hugmodel.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/kerascallbacks.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/kerasmodel.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/metrics.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/pbar.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/plots.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/soup.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/stacker.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/summary.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/utils.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras/vlog.py -> torchkeras-4.0.5/torchkeras
# copying torchkeras.egg-info/PKG-INFO -> torchkeras-4.0.5/torchkeras.egg-info
# copying torchkeras.egg-info/SOURCES.txt -> torchkeras-4.0.5/torchkeras.egg-info
# copying torchkeras.egg-info/dependency_links.txt -> torchkeras-4.0.5/torchkeras.egg-info
# copying torchkeras.egg-info/top_level.txt -> torchkeras-4.0.5/torchkeras.egg-info
# copying torchkeras/assets/SimHei.ttf -> torchkeras-4.0.5/torchkeras/assets
# copying torchkeras/assets/park.jpg -> torchkeras-4.0.5/torchkeras/assets
# copying torchkeras/assets/zidane.jpg -> torchkeras-4.0.5/torchkeras/assets
# copying torchkeras/chat/__init__.py -> torchkeras-4.0.5/torchkeras/chat
# copying torchkeras/chat/chatgpt.py -> torchkeras-4.0.5/torchkeras/chat
# copying torchkeras/chat/chatllm.py -> torchkeras-4.0.5/torchkeras/chat
# copying torchkeras/chat/ollama.py -> torchkeras-4.0.5/torchkeras/chat
# copying torchkeras/tabular/__init__.py -> torchkeras-4.0.5/torchkeras/tabular
# copying torchkeras/tabular/step_runner.py -> torchkeras-4.0.5/torchkeras/tabular
# copying torchkeras/tabular/tabular_dataset.py -> torchkeras-4.0.5/torchkeras/tabular
# copying torchkeras/tabular/tabular_preprocess.py -> torchkeras-4.0.5/torchkeras/tabular
# copying torchkeras/tabular/config/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/config
# copying torchkeras/tabular/config/config.py -> torchkeras-4.0.5/torchkeras/tabular/config
# copying torchkeras/tabular/models/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models
# copying torchkeras/tabular/models/base_model.py -> torchkeras-4.0.5/torchkeras/tabular/models
# copying torchkeras/tabular/models/autoint/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/autoint
# copying torchkeras/tabular/models/autoint/autoint.py -> torchkeras-4.0.5/torchkeras/tabular/models/autoint
# copying torchkeras/tabular/models/autoint/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/autoint
# copying torchkeras/tabular/models/category_embedding/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/category_embedding
# copying torchkeras/tabular/models/category_embedding/category_embedding_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/category_embedding
# copying torchkeras/tabular/models/category_embedding/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/category_embedding
# copying torchkeras/tabular/models/common/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/common
# copying torchkeras/tabular/models/common/heads/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/heads
# copying torchkeras/tabular/models/common/heads/blocks.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/heads
# copying torchkeras/tabular/models/common/heads/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/heads
# copying torchkeras/tabular/models/common/layers/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/activations.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/batch_norm.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/embeddings.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/gated_units.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/misc.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/soft_trees.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/transformers.py -> torchkeras-4.0.5/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/danet/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/danet
# copying torchkeras/tabular/models/danet/arch_blocks.py -> torchkeras-4.0.5/torchkeras/tabular/models/danet
# copying torchkeras/tabular/models/danet/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/danet
# copying torchkeras/tabular/models/danet/danet.py -> torchkeras-4.0.5/torchkeras/tabular/models/danet
# copying torchkeras/tabular/models/deepcross/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/deepcross
# copying torchkeras/tabular/models/deepcross/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/deepcross
# copying torchkeras/tabular/models/deepcross/deepcross_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/deepcross
# copying torchkeras/tabular/models/deepfm/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/deepfm
# copying torchkeras/tabular/models/deepfm/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/deepfm
# copying torchkeras/tabular/models/deepfm/deepfm_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/deepfm
# copying torchkeras/tabular/models/deepknn/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/deepknn
# copying torchkeras/tabular/models/deepknn/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/deepknn
# copying torchkeras/tabular/models/deepknn/deepknn_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/deepknn
# copying torchkeras/tabular/models/fm/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/fm
# copying torchkeras/tabular/models/fm/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/fm
# copying torchkeras/tabular/models/fm/fm_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/fm
# copying torchkeras/tabular/models/ft_transformer/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/ft_transformer
# copying torchkeras/tabular/models/ft_transformer/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/ft_transformer
# copying torchkeras/tabular/models/ft_transformer/ft_transformer.py -> torchkeras-4.0.5/torchkeras/tabular/models/ft_transformer
# copying torchkeras/tabular/models/gandalf/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/gandalf
# copying torchkeras/tabular/models/gandalf/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/gandalf
# copying torchkeras/tabular/models/gandalf/gandalf.py -> torchkeras-4.0.5/torchkeras/tabular/models/gandalf
# copying torchkeras/tabular/models/gate/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/gate
# copying torchkeras/tabular/models/gate/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/gate
# copying torchkeras/tabular/models/gate/gate_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/gate
# copying torchkeras/tabular/models/node/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/node
# copying torchkeras/tabular/models/node/architecture_blocks.py -> torchkeras-4.0.5/torchkeras/tabular/models/node
# copying torchkeras/tabular/models/node/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/node
# copying torchkeras/tabular/models/node/node_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/node
# copying torchkeras/tabular/models/pemlp/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/pemlp
# copying torchkeras/tabular/models/pemlp/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/pemlp
# copying torchkeras/tabular/models/pemlp/pemlp_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/pemlp
# copying torchkeras/tabular/models/tab_transformer/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/tab_transformer
# copying torchkeras/tabular/models/tab_transformer/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/tab_transformer
# copying torchkeras/tabular/models/tab_transformer/tab_transformer.py -> torchkeras-4.0.5/torchkeras/tabular/models/tab_transformer
# copying torchkeras/tabular/models/tabm/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/tabm
# copying torchkeras/tabular/models/tabm/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/tabm
# copying torchkeras/tabular/models/tabm/tabm_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/tabm
# copying torchkeras/tabular/models/tabnet/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/models/tabnet
# copying torchkeras/tabular/models/tabnet/config.py -> torchkeras-4.0.5/torchkeras/tabular/models/tabnet
# copying torchkeras/tabular/models/tabnet/tabnet_model.py -> torchkeras-4.0.5/torchkeras/tabular/models/tabnet
# copying torchkeras/tabular/utils/__init__.py -> torchkeras-4.0.5/torchkeras/tabular/utils
# copying torchkeras/tabular/utils/data_utils.py -> torchkeras-4.0.5/torchkeras/tabular/utils
# copying torchkeras/tabular/utils/nn_utils.py -> torchkeras-4.0.5/torchkeras/tabular/utils
# copying torchkeras/tabular/utils/python_utils.py -> torchkeras-4.0.5/torchkeras/tabular/utils
# copying torchkeras/tools/__init__.py -> torchkeras-4.0.5/torchkeras/tools
# copying torchkeras/tools/catboost.py -> torchkeras-4.0.5/torchkeras/tools
# copying torchkeras/tools/lightgbm.py -> torchkeras-4.0.5/torchkeras/tools
# copying torchkeras/tools/lightning.py -> torchkeras-4.0.5/torchkeras/tools
# copying torchkeras/tools/transformers.py -> torchkeras-4.0.5/torchkeras/tools
# copying torchkeras/tools/ultralytics.py -> torchkeras-4.0.5/torchkeras/tools
# copying torchkeras/vision/__init__.py -> torchkeras-4.0.5/torchkeras/vision
# copying torchkeras/vision/resnet.py -> torchkeras-4.0.5/torchkeras/vision
# copying torchkeras/vision/ssd.py -> torchkeras-4.0.5/torchkeras/vision
# copying torchkeras/vision/unet.py -> torchkeras-4.0.5/torchkeras/vision
# copying torchkeras.egg-info/SOURCES.txt -> torchkeras-4.0.5/torchkeras.egg-info
# Writing torchkeras-4.0.5/setup.cfg
# creating dist
# Creating tar archive
# removing 'torchkeras-4.0.5' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# creating build/lib/torchkeras
# copying torchkeras/metrics.py -> build/lib/torchkeras
# copying torchkeras/hugmodel.py -> build/lib/torchkeras
# copying torchkeras/__init__.py -> build/lib/torchkeras
# copying torchkeras/stacker.py -> build/lib/torchkeras
# copying torchkeras/soup.py -> build/lib/torchkeras
# copying torchkeras/kerasmodel.py -> build/lib/torchkeras
# copying torchkeras/vlog.py -> build/lib/torchkeras
# copying torchkeras/summary.py -> build/lib/torchkeras
# copying torchkeras/eda.py -> build/lib/torchkeras
# copying torchkeras/plots.py -> build/lib/torchkeras
# copying torchkeras/utils.py -> build/lib/torchkeras
# copying torchkeras/email.py -> build/lib/torchkeras
# copying torchkeras/pbar.py -> build/lib/torchkeras
# copying torchkeras/data.py -> build/lib/torchkeras
# copying torchkeras/kerascallbacks.py -> build/lib/torchkeras
# creating build/lib/torchkeras/tools
# copying torchkeras/tools/lightgbm.py -> build/lib/torchkeras/tools
# copying torchkeras/tools/transformers.py -> build/lib/torchkeras/tools
# copying torchkeras/tools/catboost.py -> build/lib/torchkeras/tools
# copying torchkeras/tools/__init__.py -> build/lib/torchkeras/tools
# copying torchkeras/tools/lightning.py -> build/lib/torchkeras/tools
# copying torchkeras/tools/ultralytics.py -> build/lib/torchkeras/tools
# creating build/lib/torchkeras/chat
# copying torchkeras/chat/chatllm.py -> build/lib/torchkeras/chat
# copying torchkeras/chat/__init__.py -> build/lib/torchkeras/chat
# copying torchkeras/chat/chatgpt.py -> build/lib/torchkeras/chat
# copying torchkeras/chat/ollama.py -> build/lib/torchkeras/chat
# creating build/lib/torchkeras/tabular
# copying torchkeras/tabular/__init__.py -> build/lib/torchkeras/tabular
# copying torchkeras/tabular/tabular_dataset.py -> build/lib/torchkeras/tabular
# copying torchkeras/tabular/tabular_preprocess.py -> build/lib/torchkeras/tabular
# copying torchkeras/tabular/step_runner.py -> build/lib/torchkeras/tabular
# creating build/lib/torchkeras/vision
# copying torchkeras/vision/ssd.py -> build/lib/torchkeras/vision
# copying torchkeras/vision/unet.py -> build/lib/torchkeras/vision
# copying torchkeras/vision/__init__.py -> build/lib/torchkeras/vision
# copying torchkeras/vision/resnet.py -> build/lib/torchkeras/vision
# creating build/lib/torchkeras/tabular/config
# copying torchkeras/tabular/config/config.py -> build/lib/torchkeras/tabular/config
# copying torchkeras/tabular/config/__init__.py -> build/lib/torchkeras/tabular/config
# creating build/lib/torchkeras/tabular/utils
# copying torchkeras/tabular/utils/__init__.py -> build/lib/torchkeras/tabular/utils
# copying torchkeras/tabular/utils/data_utils.py -> build/lib/torchkeras/tabular/utils
# copying torchkeras/tabular/utils/python_utils.py -> build/lib/torchkeras/tabular/utils
# copying torchkeras/tabular/utils/nn_utils.py -> build/lib/torchkeras/tabular/utils
# creating build/lib/torchkeras/tabular/models
# copying torchkeras/tabular/models/__init__.py -> build/lib/torchkeras/tabular/models
# copying torchkeras/tabular/models/base_model.py -> build/lib/torchkeras/tabular/models
# creating build/lib/torchkeras/tabular/models/autoint
# copying torchkeras/tabular/models/autoint/config.py -> build/lib/torchkeras/tabular/models/autoint
# copying torchkeras/tabular/models/autoint/__init__.py -> build/lib/torchkeras/tabular/models/autoint
# copying torchkeras/tabular/models/autoint/autoint.py -> build/lib/torchkeras/tabular/models/autoint
# creating build/lib/torchkeras/tabular/models/deepcross
# copying torchkeras/tabular/models/deepcross/config.py -> build/lib/torchkeras/tabular/models/deepcross
# copying torchkeras/tabular/models/deepcross/deepcross_model.py -> build/lib/torchkeras/tabular/models/deepcross
# copying torchkeras/tabular/models/deepcross/__init__.py -> build/lib/torchkeras/tabular/models/deepcross
# creating build/lib/torchkeras/tabular/models/fm
# copying torchkeras/tabular/models/fm/config.py -> build/lib/torchkeras/tabular/models/fm
# copying torchkeras/tabular/models/fm/__init__.py -> build/lib/torchkeras/tabular/models/fm
# copying torchkeras/tabular/models/fm/fm_model.py -> build/lib/torchkeras/tabular/models/fm
# creating build/lib/torchkeras/tabular/models/pemlp
# copying torchkeras/tabular/models/pemlp/config.py -> build/lib/torchkeras/tabular/models/pemlp
# copying torchkeras/tabular/models/pemlp/pemlp_model.py -> build/lib/torchkeras/tabular/models/pemlp
# copying torchkeras/tabular/models/pemlp/__init__.py -> build/lib/torchkeras/tabular/models/pemlp
# creating build/lib/torchkeras/tabular/models/common
# copying torchkeras/tabular/models/common/__init__.py -> build/lib/torchkeras/tabular/models/common
# creating build/lib/torchkeras/tabular/models/deepknn
# copying torchkeras/tabular/models/deepknn/config.py -> build/lib/torchkeras/tabular/models/deepknn
# copying torchkeras/tabular/models/deepknn/deepknn_model.py -> build/lib/torchkeras/tabular/models/deepknn
# copying torchkeras/tabular/models/deepknn/__init__.py -> build/lib/torchkeras/tabular/models/deepknn
# creating build/lib/torchkeras/tabular/models/tabm
# copying torchkeras/tabular/models/tabm/config.py -> build/lib/torchkeras/tabular/models/tabm
# copying torchkeras/tabular/models/tabm/__init__.py -> build/lib/torchkeras/tabular/models/tabm
# copying torchkeras/tabular/models/tabm/tabm_model.py -> build/lib/torchkeras/tabular/models/tabm
# creating build/lib/torchkeras/tabular/models/tabnet
# copying torchkeras/tabular/models/tabnet/config.py -> build/lib/torchkeras/tabular/models/tabnet
# copying torchkeras/tabular/models/tabnet/__init__.py -> build/lib/torchkeras/tabular/models/tabnet
# copying torchkeras/tabular/models/tabnet/tabnet_model.py -> build/lib/torchkeras/tabular/models/tabnet
# creating build/lib/torchkeras/tabular/models/ft_transformer
# copying torchkeras/tabular/models/ft_transformer/ft_transformer.py -> build/lib/torchkeras/tabular/models/ft_transformer
# copying torchkeras/tabular/models/ft_transformer/config.py -> build/lib/torchkeras/tabular/models/ft_transformer
# copying torchkeras/tabular/models/ft_transformer/__init__.py -> build/lib/torchkeras/tabular/models/ft_transformer
# creating build/lib/torchkeras/tabular/models/gate
# copying torchkeras/tabular/models/gate/gate_model.py -> build/lib/torchkeras/tabular/models/gate
# copying torchkeras/tabular/models/gate/config.py -> build/lib/torchkeras/tabular/models/gate
# copying torchkeras/tabular/models/gate/__init__.py -> build/lib/torchkeras/tabular/models/gate
# creating build/lib/torchkeras/tabular/models/category_embedding
# copying torchkeras/tabular/models/category_embedding/config.py -> build/lib/torchkeras/tabular/models/category_embedding
# copying torchkeras/tabular/models/category_embedding/__init__.py -> build/lib/torchkeras/tabular/models/category_embedding
# copying torchkeras/tabular/models/category_embedding/category_embedding_model.py -> build/lib/torchkeras/tabular/models/category_embedding
# creating build/lib/torchkeras/tabular/models/danet
# copying torchkeras/tabular/models/danet/config.py -> build/lib/torchkeras/tabular/models/danet
# copying torchkeras/tabular/models/danet/__init__.py -> build/lib/torchkeras/tabular/models/danet
# copying torchkeras/tabular/models/danet/arch_blocks.py -> build/lib/torchkeras/tabular/models/danet
# copying torchkeras/tabular/models/danet/danet.py -> build/lib/torchkeras/tabular/models/danet
# creating build/lib/torchkeras/tabular/models/deepfm
# copying torchkeras/tabular/models/deepfm/config.py -> build/lib/torchkeras/tabular/models/deepfm
# copying torchkeras/tabular/models/deepfm/__init__.py -> build/lib/torchkeras/tabular/models/deepfm
# copying torchkeras/tabular/models/deepfm/deepfm_model.py -> build/lib/torchkeras/tabular/models/deepfm
# creating build/lib/torchkeras/tabular/models/tab_transformer
# copying torchkeras/tabular/models/tab_transformer/config.py -> build/lib/torchkeras/tabular/models/tab_transformer
# copying torchkeras/tabular/models/tab_transformer/__init__.py -> build/lib/torchkeras/tabular/models/tab_transformer
# copying torchkeras/tabular/models/tab_transformer/tab_transformer.py -> build/lib/torchkeras/tabular/models/tab_transformer
# creating build/lib/torchkeras/tabular/models/node
# copying torchkeras/tabular/models/node/node_model.py -> build/lib/torchkeras/tabular/models/node
# copying torchkeras/tabular/models/node/config.py -> build/lib/torchkeras/tabular/models/node
# copying torchkeras/tabular/models/node/__init__.py -> build/lib/torchkeras/tabular/models/node
# copying torchkeras/tabular/models/node/architecture_blocks.py -> build/lib/torchkeras/tabular/models/node
# creating build/lib/torchkeras/tabular/models/gandalf
# copying torchkeras/tabular/models/gandalf/config.py -> build/lib/torchkeras/tabular/models/gandalf
# copying torchkeras/tabular/models/gandalf/__init__.py -> build/lib/torchkeras/tabular/models/gandalf
# copying torchkeras/tabular/models/gandalf/gandalf.py -> build/lib/torchkeras/tabular/models/gandalf
# creating build/lib/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/misc.py -> build/lib/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/transformers.py -> build/lib/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/activations.py -> build/lib/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/__init__.py -> build/lib/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/gated_units.py -> build/lib/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/embeddings.py -> build/lib/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/batch_norm.py -> build/lib/torchkeras/tabular/models/common/layers
# copying torchkeras/tabular/models/common/layers/soft_trees.py -> build/lib/torchkeras/tabular/models/common/layers
# creating build/lib/torchkeras/tabular/models/common/heads
# copying torchkeras/tabular/models/common/heads/config.py -> build/lib/torchkeras/tabular/models/common/heads
# copying torchkeras/tabular/models/common/heads/__init__.py -> build/lib/torchkeras/tabular/models/common/heads
# copying torchkeras/tabular/models/common/heads/blocks.py -> build/lib/torchkeras/tabular/models/common/heads
# creating build/lib/torchkeras/assets
# copying torchkeras/assets/SimHei.ttf -> build/lib/torchkeras/assets
# copying torchkeras/assets/park.jpg -> build/lib/torchkeras/assets
# copying torchkeras/assets/zidane.jpg -> build/lib/torchkeras/assets
# installing to build/bdist.macosx-11.0-arm64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-11.0-arm64/wheel
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/metrics.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tools
# copying build/lib/torchkeras/tools/lightgbm.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tools
# copying build/lib/torchkeras/tools/transformers.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tools
# copying build/lib/torchkeras/tools/catboost.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tools
# copying build/lib/torchkeras/tools/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tools
# copying build/lib/torchkeras/tools/lightning.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tools
# copying build/lib/torchkeras/tools/ultralytics.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tools
# copying build/lib/torchkeras/hugmodel.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/chat
# copying build/lib/torchkeras/chat/chatllm.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/chat
# copying build/lib/torchkeras/chat/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/chat
# copying build/lib/torchkeras/chat/chatgpt.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/chat
# copying build/lib/torchkeras/chat/ollama.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/chat
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/config
# copying build/lib/torchkeras/tabular/config/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/config
# copying build/lib/torchkeras/tabular/config/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/config
# copying build/lib/torchkeras/tabular/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/utils
# copying build/lib/torchkeras/tabular/utils/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/utils
# copying build/lib/torchkeras/tabular/utils/data_utils.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/utils
# copying build/lib/torchkeras/tabular/utils/python_utils.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/utils
# copying build/lib/torchkeras/tabular/utils/nn_utils.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/utils
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/autoint
# copying build/lib/torchkeras/tabular/models/autoint/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/autoint
# copying build/lib/torchkeras/tabular/models/autoint/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/autoint
# copying build/lib/torchkeras/tabular/models/autoint/autoint.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/autoint
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/deepcross
# copying build/lib/torchkeras/tabular/models/deepcross/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/deepcross
# copying build/lib/torchkeras/tabular/models/deepcross/deepcross_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/deepcross
# copying build/lib/torchkeras/tabular/models/deepcross/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/deepcross
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/fm
# copying build/lib/torchkeras/tabular/models/fm/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/fm
# copying build/lib/torchkeras/tabular/models/fm/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/fm
# copying build/lib/torchkeras/tabular/models/fm/fm_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/fm
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/pemlp
# copying build/lib/torchkeras/tabular/models/pemlp/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/pemlp
# copying build/lib/torchkeras/tabular/models/pemlp/pemlp_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/pemlp
# copying build/lib/torchkeras/tabular/models/pemlp/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/pemlp
# copying build/lib/torchkeras/tabular/models/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models
# copying build/lib/torchkeras/tabular/models/base_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/common
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/common/layers
# copying build/lib/torchkeras/tabular/models/common/layers/misc.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/layers
# copying build/lib/torchkeras/tabular/models/common/layers/transformers.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/layers
# copying build/lib/torchkeras/tabular/models/common/layers/activations.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/layers
# copying build/lib/torchkeras/tabular/models/common/layers/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/layers
# copying build/lib/torchkeras/tabular/models/common/layers/gated_units.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/layers
# copying build/lib/torchkeras/tabular/models/common/layers/embeddings.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/layers
# copying build/lib/torchkeras/tabular/models/common/layers/batch_norm.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/layers
# copying build/lib/torchkeras/tabular/models/common/layers/soft_trees.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/layers
# copying build/lib/torchkeras/tabular/models/common/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/common/heads
# copying build/lib/torchkeras/tabular/models/common/heads/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/heads
# copying build/lib/torchkeras/tabular/models/common/heads/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/heads
# copying build/lib/torchkeras/tabular/models/common/heads/blocks.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/common/heads
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/deepknn
# copying build/lib/torchkeras/tabular/models/deepknn/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/deepknn
# copying build/lib/torchkeras/tabular/models/deepknn/deepknn_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/deepknn
# copying build/lib/torchkeras/tabular/models/deepknn/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/deepknn
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/tabm
# copying build/lib/torchkeras/tabular/models/tabm/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/tabm
# copying build/lib/torchkeras/tabular/models/tabm/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/tabm
# copying build/lib/torchkeras/tabular/models/tabm/tabm_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/tabm
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/tabnet
# copying build/lib/torchkeras/tabular/models/tabnet/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/tabnet
# copying build/lib/torchkeras/tabular/models/tabnet/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/tabnet
# copying build/lib/torchkeras/tabular/models/tabnet/tabnet_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/tabnet
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/ft_transformer
# copying build/lib/torchkeras/tabular/models/ft_transformer/ft_transformer.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/ft_transformer
# copying build/lib/torchkeras/tabular/models/ft_transformer/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/ft_transformer
# copying build/lib/torchkeras/tabular/models/ft_transformer/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/ft_transformer
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/gate
# copying build/lib/torchkeras/tabular/models/gate/gate_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/gate
# copying build/lib/torchkeras/tabular/models/gate/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/gate
# copying build/lib/torchkeras/tabular/models/gate/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/gate
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/category_embedding
# copying build/lib/torchkeras/tabular/models/category_embedding/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/category_embedding
# copying build/lib/torchkeras/tabular/models/category_embedding/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/category_embedding
# copying build/lib/torchkeras/tabular/models/category_embedding/category_embedding_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/category_embedding
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/danet
# copying build/lib/torchkeras/tabular/models/danet/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/danet
# copying build/lib/torchkeras/tabular/models/danet/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/danet
# copying build/lib/torchkeras/tabular/models/danet/arch_blocks.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/danet
# copying build/lib/torchkeras/tabular/models/danet/danet.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/danet
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/deepfm
# copying build/lib/torchkeras/tabular/models/deepfm/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/deepfm
# copying build/lib/torchkeras/tabular/models/deepfm/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/deepfm
# copying build/lib/torchkeras/tabular/models/deepfm/deepfm_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/deepfm
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/tab_transformer
# copying build/lib/torchkeras/tabular/models/tab_transformer/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/tab_transformer
# copying build/lib/torchkeras/tabular/models/tab_transformer/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/tab_transformer
# copying build/lib/torchkeras/tabular/models/tab_transformer/tab_transformer.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/tab_transformer
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/node
# copying build/lib/torchkeras/tabular/models/node/node_model.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/node
# copying build/lib/torchkeras/tabular/models/node/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/node
# copying build/lib/torchkeras/tabular/models/node/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/node
# copying build/lib/torchkeras/tabular/models/node/architecture_blocks.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/node
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tabular/models/gandalf
# copying build/lib/torchkeras/tabular/models/gandalf/config.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/gandalf
# copying build/lib/torchkeras/tabular/models/gandalf/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/gandalf
# copying build/lib/torchkeras/tabular/models/gandalf/gandalf.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular/models/gandalf
# copying build/lib/torchkeras/tabular/tabular_dataset.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular
# copying build/lib/torchkeras/tabular/tabular_preprocess.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular
# copying build/lib/torchkeras/tabular/step_runner.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/tabular
# copying build/lib/torchkeras/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/stacker.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/vision
# copying build/lib/torchkeras/vision/ssd.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/vision
# copying build/lib/torchkeras/vision/unet.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/vision
# copying build/lib/torchkeras/vision/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/vision
# copying build/lib/torchkeras/vision/resnet.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/vision
# copying build/lib/torchkeras/soup.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/kerasmodel.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/vlog.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/summary.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/eda.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/plots.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/utils.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/email.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/pbar.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/assets
# copying build/lib/torchkeras/assets/park.jpg -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/assets
# copying build/lib/torchkeras/assets/SimHei.ttf -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/assets
# copying build/lib/torchkeras/assets/zidane.jpg -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras/assets
# copying build/lib/torchkeras/data.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# copying build/lib/torchkeras/kerascallbacks.py -> build/bdist.macosx-11.0-arm64/wheel/./torchkeras
# running install_egg_info
# Copying torchkeras.egg-info to build/bdist.macosx-11.0-arm64/wheel/./torchkeras-4.0.5-py3.12.egg-info
# running install_scripts
# /Users/admin/miniforge3/lib/python3.12/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'torchkeras.assets' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'torchkeras.assets' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'torchkeras.assets' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'torchkeras.assets' to be distributed and are
#         already explicitly excluding 'torchkeras.assets' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /Users/admin/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/cmd.py:90: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         By 2025-Oct-31, you need to update your project and remove deprecated calls
#         or your builds will no longer be supported.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras-4.0.5.dist-info/WHEEL
# creating 'dist/torchkeras-4.0.5-py3-none-any.whl' and adding 'build/bdist.macosx-11.0-arm64/wheel' to it
# adding 'torchkeras/__init__.py'
# adding 'torchkeras/data.py'
# adding 'torchkeras/eda.py'
# adding 'torchkeras/email.py'
# adding 'torchkeras/hugmodel.py'
# adding 'torchkeras/kerascallbacks.py'
# adding 'torchkeras/kerasmodel.py'
# adding 'torchkeras/metrics.py'
# adding 'torchkeras/pbar.py'
# adding 'torchkeras/plots.py'
# adding 'torchkeras/soup.py'
# adding 'torchkeras/stacker.py'
# adding 'torchkeras/summary.py'
# adding 'torchkeras/utils.py'
# adding 'torchkeras/vlog.py'
# adding 'torchkeras/assets/SimHei.ttf'
# adding 'torchkeras/assets/park.jpg'
# adding 'torchkeras/assets/zidane.jpg'
# adding 'torchkeras/chat/__init__.py'
# adding 'torchkeras/chat/chatgpt.py'
# adding 'torchkeras/chat/chatllm.py'
# adding 'torchkeras/chat/ollama.py'
# adding 'torchkeras/tabular/__init__.py'
# adding 'torchkeras/tabular/step_runner.py'
# adding 'torchkeras/tabular/tabular_dataset.py'
# adding 'torchkeras/tabular/tabular_preprocess.py'
# adding 'torchkeras/tabular/config/__init__.py'
# adding 'torchkeras/tabular/config/config.py'
# adding 'torchkeras/tabular/models/__init__.py'
# adding 'torchkeras/tabular/models/base_model.py'
# adding 'torchkeras/tabular/models/autoint/__init__.py'
# adding 'torchkeras/tabular/models/autoint/autoint.py'
# adding 'torchkeras/tabular/models/autoint/config.py'
# adding 'torchkeras/tabular/models/category_embedding/__init__.py'
# adding 'torchkeras/tabular/models/category_embedding/category_embedding_model.py'
# adding 'torchkeras/tabular/models/category_embedding/config.py'
# adding 'torchkeras/tabular/models/common/__init__.py'
# adding 'torchkeras/tabular/models/common/heads/__init__.py'
# adding 'torchkeras/tabular/models/common/heads/blocks.py'
# adding 'torchkeras/tabular/models/common/heads/config.py'
# adding 'torchkeras/tabular/models/common/layers/__init__.py'
# adding 'torchkeras/tabular/models/common/layers/activations.py'
# adding 'torchkeras/tabular/models/common/layers/batch_norm.py'
# adding 'torchkeras/tabular/models/common/layers/embeddings.py'
# adding 'torchkeras/tabular/models/common/layers/gated_units.py'
# adding 'torchkeras/tabular/models/common/layers/misc.py'
# adding 'torchkeras/tabular/models/common/layers/soft_trees.py'
# adding 'torchkeras/tabular/models/common/layers/transformers.py'
# adding 'torchkeras/tabular/models/danet/__init__.py'
# adding 'torchkeras/tabular/models/danet/arch_blocks.py'
# adding 'torchkeras/tabular/models/danet/config.py'
# adding 'torchkeras/tabular/models/danet/danet.py'
# adding 'torchkeras/tabular/models/deepcross/__init__.py'
# adding 'torchkeras/tabular/models/deepcross/config.py'
# adding 'torchkeras/tabular/models/deepcross/deepcross_model.py'
# adding 'torchkeras/tabular/models/deepfm/__init__.py'
# adding 'torchkeras/tabular/models/deepfm/config.py'
# adding 'torchkeras/tabular/models/deepfm/deepfm_model.py'
# adding 'torchkeras/tabular/models/deepknn/__init__.py'
# adding 'torchkeras/tabular/models/deepknn/config.py'
# adding 'torchkeras/tabular/models/deepknn/deepknn_model.py'
# adding 'torchkeras/tabular/models/fm/__init__.py'
# adding 'torchkeras/tabular/models/fm/config.py'
# adding 'torchkeras/tabular/models/fm/fm_model.py'
# adding 'torchkeras/tabular/models/ft_transformer/__init__.py'
# adding 'torchkeras/tabular/models/ft_transformer/config.py'
# adding 'torchkeras/tabular/models/ft_transformer/ft_transformer.py'
# adding 'torchkeras/tabular/models/gandalf/__init__.py'
# adding 'torchkeras/tabular/models/gandalf/config.py'
# adding 'torchkeras/tabular/models/gandalf/gandalf.py'
# adding 'torchkeras/tabular/models/gate/__init__.py'
# adding 'torchkeras/tabular/models/gate/config.py'
# adding 'torchkeras/tabular/models/gate/gate_model.py'
# adding 'torchkeras/tabular/models/node/__init__.py'
# adding 'torchkeras/tabular/models/node/architecture_blocks.py'
# adding 'torchkeras/tabular/models/node/config.py'
# adding 'torchkeras/tabular/models/node/node_model.py'
# adding 'torchkeras/tabular/models/pemlp/__init__.py'
# adding 'torchkeras/tabular/models/pemlp/config.py'
# adding 'torchkeras/tabular/models/pemlp/pemlp_model.py'
# adding 'torchkeras/tabular/models/tab_transformer/__init__.py'
# adding 'torchkeras/tabular/models/tab_transformer/config.py'
# adding 'torchkeras/tabular/models/tab_transformer/tab_transformer.py'
# adding 'torchkeras/tabular/models/tabm/__init__.py'
# adding 'torchkeras/tabular/models/tabm/config.py'
# adding 'torchkeras/tabular/models/tabm/tabm_model.py'
# adding 'torchkeras/tabular/models/tabnet/__init__.py'
# adding 'torchkeras/tabular/models/tabnet/config.py'
# adding 'torchkeras/tabular/models/tabnet/tabnet_model.py'
# adding 'torchkeras/tabular/utils/__init__.py'
# adding 'torchkeras/tabular/utils/data_utils.py'
# adding 'torchkeras/tabular/utils/nn_utils.py'
# adding 'torchkeras/tabular/utils/python_utils.py'
# adding 'torchkeras/tools/__init__.py'
# adding 'torchkeras/tools/catboost.py'
# adding 'torchkeras/tools/lightgbm.py'
# adding 'torchkeras/tools/lightning.py'
# adding 'torchkeras/tools/transformers.py'
# adding 'torchkeras/tools/ultralytics.py'
# adding 'torchkeras/vision/__init__.py'
# adding 'torchkeras/vision/resnet.py'
# adding 'torchkeras/vision/ssd.py'
# adding 'torchkeras/vision/unet.py'
# adding 'torchkeras-4.0.5.dist-info/licenses/LICENSE'
# adding 'torchkeras-4.0.5.dist-info/METADATA'
# adding 'torchkeras-4.0.5.dist-info/WHEEL'
# adding 'torchkeras-4.0.5.dist-info/top_level.txt'
# adding 'torchkeras-4.0.5.dist-info/RECORD'
# removing build/bdist.macosx-11.0-arm64/wheel

# %%
# !pip install torchkeras

# %%
#!pip install --user --upgrade twine

# %%
# upload the repository to pypi (test)
#!python3 -m twine upload --repository-url https://test.pypi.org/legacy/ dist/*
#!python3 -m twine upload  dist/*

# %%
# install the repository from pypi (test)
#!python3 -m pip install --index-url https://test.pypi.org/simple/ --no-deps torchkeras

# %%
# 清理之前的构建文件
# !rm -rf build dist *.egg-info
# 重新构建项目
# !python setup.py clean --all sdist bdist_wheel
# 发布

# %%
# 安装 twine（如果需要）
# !pip install --user --upgrade twine

# %%
# 使用 twine 发布到 PyPI
# !python -m twine upload dist/*

# %% [markdown]
# ## 2，Upload to github

# %%
# !git config --global user.name "lyhue1991"
# !git config --global user.email "lyhue1991@163.com"

# %%
#!git reset 9b060d7db1653627bc725f7b65283cb4d6ae799d

# %%
# !git init
# Out:
# Initialized empty Git repository in /Users/admin/Codes/torchkeras/.git/

# %%
# !git add -A

# %%
# !git commit -m"update 4.0.5"
# Out:
# [main (root-commit) 04323b9] update 4.0.5
#  155 files changed, 265481 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 .vscode/settings.json
#  create mode 100644 "01\357\274\214kerasmodel_example.ipynb"
#  create mode 100644 "02\357\274\214kerasmodel_wandb_demo.ipynb"
#  create mode 100644 "03\357\274\214kerasmodel_tuning_demo.ipynb"
#  create mode 100644 "04\357\274\214kerasmodel_tensorboard_demo.ipynb"
#  create mode 100644 "05\357\274\214kerasmodel_ddp_tpu_examples.ipynb"
#  create mode 100644 "06\357\274\214fastai_example.ipynb"
#  create mode 100644 "07\357\274\214utils_example.ipynb"
#  create mode 100644 "08\357\274\214hugmodel_example.ipynb"
#  create mode 100644 "09\357\274\214ollama_example.ipynb"
#  create mode 100644 "10\357\274\214vlog_example.ipynb"
#  create mode 100644 LICENSE
#  create mode 100644 MANIFEST.in
#  create mode 100644 README.md
#  create mode 100644 README_en.md
#  create mode 100644 data/torchkeras_history.gif
#  create mode 100644 data/torchkeras_plot.gif
#  create mode 100644 "examples/BERT_NER\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 "examples/BERT\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 "examples/BaiChuan13B_MultiRounds\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 "examples/BaiChuan13B_NER\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 "examples/BaiChuan13B_QLoRA\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 "examples/BaiChuan2_13B\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 examples/CRNN_CTC.ipynb
#  create mode 100644 "examples/ChatGLM2_AdaLoRA\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 "examples/ChatGLM2_LoRA\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 "examples/ChatGLM2_LoRA\346\263\250\351\207\212\347\211\210.ipynb"
#  create mode 100644 "examples/ChatGLM2_QLoRA_Kaggle\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 examples/DQN.ipynb
#  create mode 100644 "examples/DeepCross\344\272\214\345\210\206\347\261\273.ipynb"
#  create mode 100644 "examples/DeepFM\344\272\214\345\210\206\347\261\273.ipynb"
#  create mode 100644 "examples/Deeplabv3plus\342\200\224\342\200\224smp.ipynb"
#  create mode 100644 examples/Dive_into_Llama.ipynb
#  create mode 100644 examples/Dive_into_Transformer.ipynb
#  create mode 100644 "examples/FM\344\272\214\345\210\206\347\261\273.ipynb"
#  create mode 100644 "examples/FTTransformer\345\233\236\345\275\222\344\273\273\345\212\241.ipynb"
#  create mode 100644 "examples/FTTransformer\345\244\232\345\210\206\347\261\273.ipynb"
#  create mode 100644 "examples/FasterRCNN\342\200\224\342\200\224vision.ipynb"
#  create mode 100644 "examples/LightGBM\344\272\214\345\210\206\347\261\273.ipynb"
#  create mode 100644 "examples/MaskRCNN\342\200\224\342\200\224detectron2.ipynb"
#  create mode 100644 examples/Q-learning.ipynb
#  create mode 100644 "examples/Qwen7B_MultiRounds\342\200\224\342\200\224transformers.ipynb"
#  create mode 100644 examples/ResNet.ipynb
#  create mode 100644 examples/SSD.ipynb
#  create mode 100644 "examples/SwinTransformer\342\200\224\342\200\224timm.ipynb"
#  create mode 100644 "examples/Tabm\345\244\232\345\210\206\347\261\273.ipynb"
#  create mode 100644 examples/UNet.ipynb
#  create mode 100644 "examples/YOLOV8_Detect\342\200\224\342\200\224ultralytics.ipynb"
#  create mode 100644 "examples/YOLOV8_Segment\342\200\224\342\200\224ultralytics.ipynb"
#  create mode 100644 kerasmodel_example.py
#  create mode 100644 push2github.ipynb
#  create mode 100644 pyproject.toml
#  create mode 100644 setup.py
#  create mode 100644 torchkeras/__init__.py
#  create mode 100644 torchkeras/assets/SimHei.ttf
#  create mode 100644 torchkeras/chat/__init__.py
#  create mode 100644 torchkeras/chat/chatgpt.py
#  create mode 100644 torchkeras/chat/chatllm.py
#  create mode 100644 torchkeras/chat/ollama.py
#  create mode 100644 torchkeras/data.py
#  create mode 100644 torchkeras/eda.py
#  create mode 100644 torchkeras/email.py
#  create mode 100644 torchkeras/hugmodel.py
#  create mode 100644 torchkeras/kerascallbacks.py
#  create mode 100644 torchkeras/kerasmodel.py
#  create mode 100644 torchkeras/metrics.py
#  create mode 100644 torchkeras/pbar.py
#  create mode 100644 torchkeras/plots.py
#  create mode 100644 torchkeras/soup.py
#  create mode 100644 torchkeras/stacker.py
#  create mode 100644 torchkeras/summary.py
#  create mode 100644 torchkeras/tabular/__init__.py
#  create mode 100644 torchkeras/tabular/config/__init__.py
#  create mode 100644 torchkeras/tabular/config/config.py
#  create mode 100644 torchkeras/tabular/models/__init__.py
#  create mode 100644 torchkeras/tabular/models/autoint/__init__.py
#  create mode 100644 torchkeras/tabular/models/autoint/autoint.py
#  create mode 100644 torchkeras/tabular/models/autoint/config.py
#  create mode 100644 torchkeras/tabular/models/base_model.py
#  create mode 100644 torchkeras/tabular/models/category_embedding/__init__.py
#  create mode 100644 torchkeras/tabular/models/category_embedding/category_embedding_model.py
#  create mode 100644 torchkeras/tabular/models/category_embedding/config.py
#  create mode 100644 torchkeras/tabular/models/common/__init__.py
#  create mode 100644 torchkeras/tabular/models/common/heads/__init__.py
#  create mode 100644 torchkeras/tabular/models/common/heads/blocks.py
#  create mode 100644 torchkeras/tabular/models/common/heads/config.py
#  create mode 100644 torchkeras/tabular/models/common/layers/__init__.py
#  create mode 100644 torchkeras/tabular/models/common/layers/activations.py
#  create mode 100644 torchkeras/tabular/models/common/layers/batch_norm.py
#  create mode 100644 torchkeras/tabular/models/common/layers/embeddings.py
#  create mode 100644 torchkeras/tabular/models/common/layers/gated_units.py
#  create mode 100644 torchkeras/tabular/models/common/layers/misc.py
#  create mode 100644 torchkeras/tabular/models/common/layers/soft_trees.py
#  create mode 100644 torchkeras/tabular/models/common/layers/transformers.py
#  create mode 100644 torchkeras/tabular/models/danet/__init__.py
#  create mode 100644 torchkeras/tabular/models/danet/arch_blocks.py
#  create mode 100644 torchkeras/tabular/models/danet/config.py
#  create mode 100644 torchkeras/tabular/models/danet/danet.py
#  create mode 100644 torchkeras/tabular/models/deepcross/__init__.py
#  create mode 100644 torchkeras/tabular/models/deepcross/config.py
#  create mode 100644 torchkeras/tabular/models/deepcross/deepcross_model.py
#  create mode 100644 torchkeras/tabular/models/deepfm/__init__.py
#  create mode 100644 torchkeras/tabular/models/deepfm/config.py
#  create mode 100644 torchkeras/tabular/models/deepfm/deepfm_model.py
#  create mode 100644 torchkeras/tabular/models/deepknn/__init__.py
#  create mode 100644 torchkeras/tabular/models/deepknn/config.py
#  create mode 100644 torchkeras/tabular/models/deepknn/deepknn_model.py
#  create mode 100644 torchkeras/tabular/models/fm/__init__.py
#  create mode 100644 torchkeras/tabular/models/fm/config.py
#  create mode 100644 torchkeras/tabular/models/fm/fm_model.py
#  create mode 100644 torchkeras/tabular/models/ft_transformer/__init__.py
#  create mode 100644 torchkeras/tabular/models/ft_transformer/config.py
#  create mode 100644 torchkeras/tabular/models/ft_transformer/ft_transformer.py
#  create mode 100644 torchkeras/tabular/models/gandalf/__init__.py
#  create mode 100644 torchkeras/tabular/models/gandalf/config.py
#  create mode 100644 torchkeras/tabular/models/gandalf/gandalf.py
#  create mode 100644 torchkeras/tabular/models/gate/__init__.py
#  create mode 100644 torchkeras/tabular/models/gate/config.py
#  create mode 100644 torchkeras/tabular/models/gate/gate_model.py
#  create mode 100644 torchkeras/tabular/models/node/__init__.py
#  create mode 100644 torchkeras/tabular/models/node/architecture_blocks.py
#  create mode 100644 torchkeras/tabular/models/node/config.py
#  create mode 100644 torchkeras/tabular/models/node/node_model.py
#  create mode 100644 torchkeras/tabular/models/pemlp/__init__.py
#  create mode 100644 torchkeras/tabular/models/pemlp/config.py
#  create mode 100644 torchkeras/tabular/models/pemlp/pemlp_model.py
#  create mode 100644 torchkeras/tabular/models/tab_transformer/__init__.py
#  create mode 100644 torchkeras/tabular/models/tab_transformer/config.py
#  create mode 100644 torchkeras/tabular/models/tab_transformer/tab_transformer.py
#  create mode 100644 torchkeras/tabular/models/tabm/__init__.py
#  create mode 100644 torchkeras/tabular/models/tabm/config.py
#  create mode 100644 torchkeras/tabular/models/tabm/tabm_model.py
#  create mode 100644 torchkeras/tabular/models/tabnet/__init__.py
#  create mode 100644 torchkeras/tabular/models/tabnet/config.py
#  create mode 100644 torchkeras/tabular/models/tabnet/tabnet_model.py
#  create mode 100644 torchkeras/tabular/step_runner.py
#  create mode 100644 torchkeras/tabular/tabular_dataset.py
#  create mode 100644 torchkeras/tabular/tabular_preprocess.py
#  create mode 100644 torchkeras/tabular/utils/__init__.py
#  create mode 100644 torchkeras/tabular/utils/data_utils.py
#  create mode 100644 torchkeras/tabular/utils/nn_utils.py
#  create mode 100644 torchkeras/tabular/utils/python_utils.py
#  create mode 100644 torchkeras/tools/__init__.py
#  create mode 100644 torchkeras/tools/catboost.py
#  create mode 100644 torchkeras/tools/lightgbm.py
#  create mode 100644 torchkeras/tools/lightning.py
#  create mode 100644 torchkeras/tools/transformers.py
#  create mode 100644 torchkeras/tools/ultralytics.py
#  create mode 100644 torchkeras/utils.py
#  create mode 100644 torchkeras/vision/__init__.py
#  create mode 100644 torchkeras/vision/resnet.py
#  create mode 100644 torchkeras/vision/ssd.py
#  create mode 100644 torchkeras/vision/unet.py
#  create mode 100644 torchkeras/vlog.py

# %%
# !git pull origin

# %%
#!git remote remove origin

# %%
# !git remote add origin git@github.com:lyhue1991/torchkeras.git

# %%
# !git push -f  origin main:master
# Out:
# Enumerating objects: 187, done.
# Counting objects: 100% (187/187), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (183/183), done.
# Writing objects: 100% (187/187), 43.30 MiB | 2.29 MiB/s, done.
# Total 187 (delta 18), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (18/18), done.
# To github.com:lyhue1991/torchkeras.git
#  + 6e65ea1...04323b9 main -> master (forced update)

# %%
# !git remote add gitee git@gitee.com:Python_Ai_Road/torchkeras.git

# %%
# !git push -f  gitee main:master
# Out:
# Enumerating objects: 187, done.
# Counting objects: 100% (187/187), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (183/183), done.
# Writing objects: 100% (187/187), 43.30 MiB | 2.27 MiB/s, done.
# Total 187 (delta 18), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (18/18), done.
# remote: Powered by GITEE.COM [1.1.5]
# remote: Set trace flag f6463ea7
# To gitee.com:Python_Ai_Road/torchkeras.git
#  + 6e65ea1...04323b9 main -> master (forced update)

# %% [markdown]
# ## 3， gitignore

# %%
# %%writefile .gitignore
# */catboost_info
# */catboost_cached_datasets
# */catboost_model
# .DS_store
# .ipynb_checkpoints
# .ipynb_checkpoints/*
# torchkeras.egg-info/*
# dist/*
# build/*
# *.ipynb_checkpoints
# torchkeras/__pycache__/
# torchkeras/models/__pycache__/
# examples/datasets/
# __pycache__
# examples/*.pt
# examples/*.png
# examples/*.md
# examples/*.zip
# examples/*.parquet
# examples/wandb/
# torchkeras/ocr/__pycache__/
# */__pycache__
# *.pyc
# torchkeras/chat/__pycache__/
# torchkeras/tools/__pycache__/
# examples/*.zip
# examples/*.pt
# examples/checkpoint
# examples/*.parquet
# examples/*.png
# examples/.ipynb_checkpoints
# examples/__pycache__/
# torchkeras/chat/__pycache__/
# .idea
# mnist
# output_dir
# wandb
# *.pt
# debug.ipynb
# cats
# ImageCleaner
# runs
# checkpoint
# *.jpg
# *.png
# Out:
# Overwriting .gitignore
