# %% [markdown]
# ### Upload to  Pypi

# %%
# %run setup.py sdist bdist_wheel
# Out:
# running sdist
# running egg_info
# creating torchkeras.egg-info
# writing torchkeras.egg-info/PKG-INFO
# writing dependency_links to torchkeras.egg-info/dependency_links.txt
# writing requirements to torchkeras.egg-info/requires.txt
# writing top-level names to torchkeras.egg-info/top_level.txt
# writing manifest file 'torchkeras.egg-info/SOURCES.txt'
# reading manifest file 'torchkeras.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'torchkeras/*.ttf'
# no previously-included directories found matching 'torchkeras/assets/*checkpoint*'
# warning: no files found matching '*.png' under directory 'torchkeras/assets'
# warning: no files found matching '*.jpeg' under directory 'torchkeras/assets'
# warning: no previously-included files matching '*' found under directory 'torchkeras/__pycache__'
# warning: no previously-included files matching '*' found under directory 'torchkeras/.ipynb_checkpoints'
# adding license file 'LICENSE'
# writing manifest file 'torchkeras.egg-info/SOURCES.txt'
# running check
# creating torchkeras-3.9.1
# creating torchkeras-3.9.1/torchkeras
# creating torchkeras-3.9.1/torchkeras.egg-info
# creating torchkeras-3.9.1/torchkeras/assets
# creating torchkeras-3.9.1/torchkeras/chat
# creating torchkeras-3.9.1/torchkeras/models
# creating torchkeras-3.9.1/torchkeras/tools
# copying files to torchkeras-3.9.1...
# copying LICENSE -> torchkeras-3.9.1
# copying MANIFEST.in -> torchkeras-3.9.1
# copying README.md -> torchkeras-3.9.1
# copying setup.py -> torchkeras-3.9.1
# copying torchkeras/__init__.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/data.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/eda.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/email.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/hugmodel.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/kerascallbacks.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/kerasmodel.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/metrics.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/pbar.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/plots.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/soup.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/summary.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras/utils.py -> torchkeras-3.9.1/torchkeras
# copying torchkeras.egg-info/PKG-INFO -> torchkeras-3.9.1/torchkeras.egg-info
# copying torchkeras.egg-info/SOURCES.txt -> torchkeras-3.9.1/torchkeras.egg-info
# copying torchkeras.egg-info/dependency_links.txt -> torchkeras-3.9.1/torchkeras.egg-info
# copying torchkeras.egg-info/requires.txt -> torchkeras-3.9.1/torchkeras.egg-info
# copying torchkeras.egg-info/top_level.txt -> torchkeras-3.9.1/torchkeras.egg-info
# copying torchkeras/assets/SimHei.ttf -> torchkeras-3.9.1/torchkeras/assets
# copying torchkeras/assets/park.jpg -> torchkeras-3.9.1/torchkeras/assets
# copying torchkeras/assets/zidane.jpg -> torchkeras-3.9.1/torchkeras/assets
# copying torchkeras/chat/__init__.py -> torchkeras-3.9.1/torchkeras/chat
# copying torchkeras/chat/chatglm.py -> torchkeras-3.9.1/torchkeras/chat
# copying torchkeras/chat/chatgpt.py -> torchkeras-3.9.1/torchkeras/chat
# copying torchkeras/models/__init__.py -> torchkeras-3.9.1/torchkeras/models
# copying torchkeras/models/resnet.py -> torchkeras-3.9.1/torchkeras/models
# copying torchkeras/models/ssd.py -> torchkeras-3.9.1/torchkeras/models
# copying torchkeras/models/unet.py -> torchkeras-3.9.1/torchkeras/models
# copying torchkeras/tools/catboost.py -> torchkeras-3.9.1/torchkeras/tools
# Writing torchkeras-3.9.1/setup.cfg
# creating dist
# Creating tar archive
# removing 'torchkeras-3.9.1' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# copying torchkeras/__init__.py -> build/lib/torchkeras
# copying torchkeras/chat/chatglm.py -> build/lib/torchkeras/chat
# creating build/lib/build
# creating build/lib/build/lib
# creating build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/metrics.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/hugmodel.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/__init__.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/soup.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/kerasmodel.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/summary.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/eda.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/plots.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/utils.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/email.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/pbar.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/data.py -> build/lib/build/lib/torchkeras
# copying build/lib/torchkeras/kerascallbacks.py -> build/lib/build/lib/torchkeras
# creating build/lib/build/lib/torchkeras/tools
# copying build/lib/torchkeras/tools/catboost.py -> build/lib/build/lib/torchkeras/tools
# creating build/lib/build/lib/torchkeras/chat
# copying build/lib/torchkeras/chat/chatglm.py -> build/lib/build/lib/torchkeras/chat
# copying build/lib/torchkeras/chat/__init__.py -> build/lib/build/lib/torchkeras/chat
# copying build/lib/torchkeras/chat/chatgpt.py -> build/lib/build/lib/torchkeras/chat
# creating build/lib/build/lib/torchkeras/models
# copying build/lib/torchkeras/models/ssd.py -> build/lib/build/lib/torchkeras/models
# copying build/lib/torchkeras/models/unet.py -> build/lib/build/lib/torchkeras/models
# copying build/lib/torchkeras/models/__init__.py -> build/lib/build/lib/torchkeras/models
# copying build/lib/torchkeras/models/resnet.py -> build/lib/build/lib/torchkeras/models
# installing to build/bdist.macosx-11.0-arm64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-11.0-arm64/wheel
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/metrics.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/tools
# copying build/lib/torchkeras/tools/catboost.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/tools
# copying build/lib/torchkeras/hugmodel.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/chat
# copying build/lib/torchkeras/chat/chatglm.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/chat
# copying build/lib/torchkeras/chat/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/chat
# copying build/lib/torchkeras/chat/chatgpt.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/chat
# copying build/lib/torchkeras/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/models
# copying build/lib/torchkeras/models/ssd.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/models
# copying build/lib/torchkeras/models/unet.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/models
# copying build/lib/torchkeras/models/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/models
# copying build/lib/torchkeras/models/resnet.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/models
# copying build/lib/torchkeras/soup.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/kerasmodel.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/summary.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/eda.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/plots.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/utils.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/email.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/pbar.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras/assets
# copying build/lib/torchkeras/assets/park.jpg -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/assets
# copying build/lib/torchkeras/assets/SimHei.ttf -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/assets
# copying build/lib/torchkeras/assets/zidane.jpg -> build/bdist.macosx-11.0-arm64/wheel/torchkeras/assets
# copying build/lib/torchkeras/data.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# copying build/lib/torchkeras/kerascallbacks.py -> build/bdist.macosx-11.0-arm64/wheel/torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/build
# creating build/bdist.macosx-11.0-arm64/wheel/build/lib
# creating build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/metrics.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/tools
# copying build/lib/build/lib/torchkeras/tools/catboost.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/tools
# copying build/lib/build/lib/torchkeras/hugmodel.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/chat
# copying build/lib/build/lib/torchkeras/chat/chatglm.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/chat
# copying build/lib/build/lib/torchkeras/chat/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/chat
# copying build/lib/build/lib/torchkeras/chat/chatgpt.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/chat
# copying build/lib/build/lib/torchkeras/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# creating build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/models
# copying build/lib/build/lib/torchkeras/models/ssd.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/models
# copying build/lib/build/lib/torchkeras/models/unet.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/models
# copying build/lib/build/lib/torchkeras/models/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/models
# copying build/lib/build/lib/torchkeras/models/resnet.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras/models
# copying build/lib/build/lib/torchkeras/soup.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/kerasmodel.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/summary.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/eda.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/plots.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/utils.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/email.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/pbar.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/data.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# copying build/lib/build/lib/torchkeras/kerascallbacks.py -> build/bdist.macosx-11.0-arm64/wheel/build/lib/torchkeras
# running install_egg_info
# Copying torchkeras.egg-info to build/bdist.macosx-11.0-arm64/wheel/torchkeras-3.9.1-py3.9.egg-info
# running install_scripts
# creating build/bdist.macosx-11.0-arm64/wheel/torchkeras-3.9.1.dist-info/WHEEL
# creating 'dist/torchkeras-3.9.1-py3-none-any.whl' and adding 'build/bdist.macosx-11.0-arm64/wheel' to it
# adding 'build/lib/torchkeras/__init__.py'
# adding 'build/lib/torchkeras/data.py'
# adding 'build/lib/torchkeras/eda.py'
# adding 'build/lib/torchkeras/email.py'
# adding 'build/lib/torchkeras/hugmodel.py'
# adding 'build/lib/torchkeras/kerascallbacks.py'
# adding 'build/lib/torchkeras/kerasmodel.py'
# adding 'build/lib/torchkeras/metrics.py'
# adding 'build/lib/torchkeras/pbar.py'
# adding 'build/lib/torchkeras/plots.py'
# adding 'build/lib/torchkeras/soup.py'
# adding 'build/lib/torchkeras/summary.py'
# adding 'build/lib/torchkeras/utils.py'
# adding 'build/lib/torchkeras/chat/__init__.py'
# adding 'build/lib/torchkeras/chat/chatglm.py'
# adding 'build/lib/torchkeras/chat/chatgpt.py'
# adding 'build/lib/torchkeras/models/__init__.py'
# adding 'build/lib/torchkeras/models/resnet.py'
# adding 'build/lib/torchkeras/models/ssd.py'
# adding 'build/lib/torchkeras/models/unet.py'
# adding 'build/lib/torchkeras/tools/catboost.py'
# adding 'torchkeras/__init__.py'
# adding 'torchkeras/data.py'
# adding 'torchkeras/eda.py'
# adding 'torchkeras/email.py'
# adding 'torchkeras/hugmodel.py'
# adding 'torchkeras/kerascallbacks.py'
# adding 'torchkeras/kerasmodel.py'
# adding 'torchkeras/metrics.py'
# adding 'torchkeras/pbar.py'
# adding 'torchkeras/plots.py'
# adding 'torchkeras/soup.py'
# adding 'torchkeras/summary.py'
# adding 'torchkeras/utils.py'
# /Users/liangyun2/miniforge3/envs/tf26/lib/python3.9/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'torchkeras.assets' as data is deprecated, please list it in `packages`.
#     !!
#
#
#     ############################
#     # Package would be ignored #
#     ############################
#     Python recognizes 'torchkeras.assets' as an importable package,
#     but it is not listed in the `packages` configuration of setuptools.
#
#     'torchkeras.assets' has been automatically added to the distribution only
#     because it may contain data files, but this behavior is likely to change
#     in future versions of setuptools (and therefore is considered deprecated).
#
#     Please make sure that 'torchkeras.assets' is included as a package by using
#     the `packages` configuration field or the proper discovery methods
#     (for example by using `find_namespace_packages(...)`/`find_namespace:`
#     instead of `find_packages(...)`/`find:`).
#
#     You can read more about "package discovery" and "data files" on setuptools
#     documentation page.
#
#
# !!
#
#   check.warn(importable)
# /Users/liangyun2/miniforge3/envs/tf26/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# adding 'torchkeras/assets/SimHei.ttf'
# adding 'torchkeras/assets/park.jpg'
# adding 'torchkeras/assets/zidane.jpg'
# adding 'torchkeras/chat/__init__.py'
# adding 'torchkeras/chat/chatglm.py'
# adding 'torchkeras/chat/chatgpt.py'
# adding 'torchkeras/models/__init__.py'
# adding 'torchkeras/models/resnet.py'
# adding 'torchkeras/models/ssd.py'
# adding 'torchkeras/models/unet.py'
# adding 'torchkeras/tools/catboost.py'
# adding 'torchkeras-3.9.1.dist-info/LICENSE'
# adding 'torchkeras-3.9.1.dist-info/METADATA'
# adding 'torchkeras-3.9.1.dist-info/WHEEL'
# adding 'torchkeras-3.9.1.dist-info/top_level.txt'
# adding 'torchkeras-3.9.1.dist-info/RECORD'
# removing build/bdist.macosx-11.0-arm64/wheel

# %%
# !pip install torchkeras

# %%
#!pip install --user --upgrade twine

# %%
# upload the repository to pypi (test)
#!python3 -m twine upload --repository-url https://test.pypi.org/legacy/ dist/*

# %%
# install the repository from pypi (test)
#!python3 -m pip install --index-url https://test.pypi.org/simple/ --no-deps torchkeras

# %% [markdown]
# ### Upload to github

# %%
# !git config --global user.name "lyhue1991"
# !git config --global user.email "lyhue1991@163.com"

# %%
# !git add -A

# %%
# !git log
# Out:
# commit d1277daa8fd0bdb907edba32c132abcf90498e8e (HEAD -> master, origin/master, gitee/master)
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jul 15 16:10:05 2023 +0800
#
#     update 3.9.2
#
# commit 88b2e233c1ad5762a0cb7cda3474f5a5186609f4
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jul 15 16:09:08 2023 +0800
#
#     update 3.9.1
#
# commit 9dbbb459204e9c829a26e6dfeda657271f965e31
# Merge: 0c0c8bd 3ea89b6
# Author: 一个有毅力的吃货 <lyhue1991@163.com>
# Date:   Thu Jul 13 12:05:42 2023 +0800
#
#     Merge pull request #34 from sawyerbutton/master
#
#     ChatGLM2-6b微调保姆级教程 - Colab支持&更多的注释详解
#
# commit 3ea89b6d6aa9255d7e2f46a556781870fa8fbe7c
# Author: sawyerbutton <linghui92liu@gmail.com>
# Date:   Thu Jul 13 12:02:11 2023 +0800
#
#     ChatGLM2-6b微调保姆级教程 - Colab支持&更多的注释详解
#
#     在Colab-pro上运行ChatGLM2-6b微调保姆级教程
#     更多的注释详解和tricy提示
#
# commit 0c0c8bd6628cbc880d52da63a3c9e4d9b7bfce1d
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jul 8 21:05:46 2023 +0800
#
#     update 3.9.1
#
# commit 9c5da28edb73c9e55a64eaa937a18d7639b88342
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Jul 7 05:34:45 2023 +0800
#
#     update 3.9.1
#
# commit b52e242d73dd2f5dc4eed57436c38ea362828ee7
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Jul 7 05:31:49 2023 +0800
#
#     update 3.9.1
#
# commit e8e99f652f4dd2e65756d72bcd17988ed6cde650
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Jul 3 00:40:32 2023 +0800
#
#     update 3.9.1
#
# commit e55750b174dc3862e1c25a666aad5c747cb7b525
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Jun 30 14:52:05 2023 +0800
#
#     update 3.9.0
#
# commit 757272e67f5e81ebc567b2d489dde0dc6993cda0
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Jun 30 09:35:33 2023 +0800
#
#     update 3.8.9
#
# commit 64fb6c1744199f8c31936c206d1097c71c83af5a
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Jun 29 21:43:16 2023 +0800
#
#     update 3.8.9
#
# commit 57d7cb5a9531061c3b4d43776c7b3a92517b2c8e
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Jun 26 00:06:26 2023 +0800
#
#     update 3.8.9
#
# commit b4686b85eb2b44dab07161f7b8d1278b868e8c44
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jun 18 22:14:45 2023 +0800
#
#     update 3.8.9
#
# commit 64ea6f657658d7e5c41784f3e2f18207b55103c8
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Jun 14 09:01:10 2023 +0800
#
#     update 3.8.9
#
# commit e9ca75ce2cea842daae07d519e63801357a6cd76
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Jun 13 22:54:52 2023 +0800
#
#     update 3.8.9
#
# commit a2b7ec7ae84d9da5890fa2bcf5874c0a3e3ee302
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Jun 12 19:22:26 2023 +0800
#
#     update 3.8.9
#
# commit 6f020275d14a868a8af10247c8f30c469633cbd6
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Jun 12 16:31:58 2023 +0800
#
#     update 3.8.9
#
# commit 8e8a01d2bef9be03981204431103b1ba91e0318f
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Jun 12 10:41:35 2023 +0800
#
#     update 3.8.8
#
# commit ca6b19efaccf808f7501af2f9029332f439284d2
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Jun 12 10:20:52 2023 +0800
#
#     update 3.8.8
#
# commit 939ba29b61e549672030a12e03e5218f55e9c915
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Jun 12 09:50:10 2023 +0800
#
#     update 3.8.8
#
# commit 3dd73b7735a3926704b989a5346a7471eb211c82
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jun 11 23:23:16 2023 +0800
#
#     update 3.8.8
#
# commit 63d98de37631d3c6d3398c3920437b90794e6ed1
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Jun 9 22:57:34 2023 +0800
#
#     update 3.8.8
#
# commit a6ed998e31ad7396e3e29acb6b401d70e057fab3
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Jun 6 10:39:19 2023 +0800
#
#     update readme
#
# commit f87426b89ee678bd389a63806ac96902f2589819
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Jun 6 06:47:14 2023 +0800
#
#     update readme
#
# commit 1f132d7d90afc1af6c3b428faeb2d52d65cba239
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jun 4 21:47:50 2023 +0800
#
#     update 3.8.7
#
# commit 41419af8068379a119ec8c0cdbccadc47417aa12
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jun 4 17:07:09 2023 +0800
#
#     update 3.8.7
#
# commit 1733bf41038a1295d420eb30b75c86d768df3f15
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jun 4 17:01:34 2023 +0800
#
#     update 3.8.7
#
# commit 5544bf4f0e1dd4c70b3ffaf1a9e716b0c6dcd46e
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jun 3 14:41:12 2023 +0800
#
#     update 3.8.7
#
# commit 04a7c898c1995e7fd69de7f83dd3afdb9400cb58
# Author: 算法美食屋 <lyhue1991@163.com>
# Date:   Sat Jun 3 06:40:09 2023 +0000
#
#     update README.md.
#
#     Signed-off-by: 算法美食屋 <lyhue1991@163.com>
#
# commit 41890fbccab5dba6ad59c1b346801bd391f89272
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jun 3 14:38:56 2023 +0800
#
#     update 3.8.7
#
# commit e6e2cbd3d80b6b7229231fa91d12d3eeed08f3ca
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jun 3 14:34:06 2023 +0800
#
#     update 3.8.7
#
# commit a6897aec876ebf3d15343b9cae9f3dc67ca67b9d
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jun 3 09:35:53 2023 +0800
#
#     update 3.8.7
#
# commit d38a8fb76426936b4adede2006542746bb3ba14e
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Jun 2 23:36:03 2023 +0800
#
#     update 3.8.7
#
# commit f5c54a6083ddac5661d8a577eb30f06e70550be6
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Jun 2 23:31:12 2023 +0800
#
#     update 3.8.7
#
# commit 3baac8447d7b699884cf7223975a81b1b9dd85cb
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Jun 1 10:28:47 2023 +0800
#
#     update 3.8.7
#
# commit 462caeb349d5b8840cf1f20e938f6658edb5871d
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed May 31 10:32:14 2023 +0800
#
#     update 3.8.7
#
# commit 4e35eec0fabb6e9b21af26af9ec7a926d9a6229b
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue May 30 23:27:15 2023 +0800
#
#     update 3.8.6
#
# commit e33d8240d13bcdaad58479c1b632959f9cae8266
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon May 29 22:32:11 2023 +0800
#
#     update 3.8.6
#
# commit 6a631b87dbd908c3f62fb657b2bff9c9d0b9164b
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun May 28 21:45:58 2023 +0800
#
#     update 3.8.6
#
# commit 008fa1c9b1c1fed4682ddfeb66898547dac960f7
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat May 27 14:01:54 2023 +0800
#
#     update 3.8.6
#
# commit b49bcae4b7098bd886cf7b7ff95fd4c6cb7e47a7
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat May 27 14:00:49 2023 +0800
#
#     update 3.8.6
#
# commit 4baccea0ec8b82d5ef0fefc425205f54269e00ea
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue May 23 10:30:37 2023 +0800
#
#     update 3.8.6
#
# commit d00003861095c7542a862f780bd884ecfd2bfb3d
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue May 23 10:08:08 2023 +0800
#
#     update 3.8.6
#
# commit 7f494bd06cb3057ebf178ab8f409010d0b561c97
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun May 21 22:25:22 2023 +0800
#
#     update 3.8.6
#
# commit 460f2d7b5a141ef546f5bc0d5c39c767dd0a96d5
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun May 21 09:55:05 2023 +0800
#
#     update 3.8.6
#
# commit 501777eefbd7648dbf336944fad9c1c0eecd0c4a
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun May 21 09:50:13 2023 +0800
#
#     update 3.8.6
#
# commit a4e042d988ddbbc72d1832371284f85acd8bb20d
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat May 20 01:28:28 2023 +0800
#
#     update 3.8.6
#
# commit acbe587e6a4fc22f7356b2d6eafd100418c5ba76
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu May 18 06:37:10 2023 +0800
#
#     update 3.8.5
#
# commit 2469b7c24636bf2562fbd3d1e78f47de01734393
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun May 14 09:57:18 2023 +0800
#
#     update 3.8.4
#
# commit 5ebff88b78b351a25b348457ab306d06c74d4762
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri May 12 18:35:42 2023 +0800
#
#     update 3.8.4
#
# commit 11618f9ef5fe0468b7c3ac3f184e67fae640cd20
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Apr 17 10:33:28 2023 +0800
#
#     update 3.8.3
#
# commit a1edda621d864ae37b8d89655fc165478217e2e5
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Apr 13 19:40:48 2023 +0800
#
#     update 3.8.3
#
# commit 0ac2361461cebc1a904a2ed078bc39cc498ae2b2
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Apr 13 17:46:48 2023 +0800
#
#     update 3.8.3
#
# commit 83949364e3c36ec30fe2e0659f802e67c6883944
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Apr 12 18:38:43 2023 +0800
#
#     update 3.8.2
#
# commit e963c9038fc38f4b2000efb41aa1a952b68dfe9f
# Author: 梁云2 <liangyun2@tuhu.cn>
# Date:   Wed Apr 12 18:18:22 2023 +0800
#
#     update 3.8.2
#
# commit 50728dd95c45b727580d477f9ed1850aa135dd25
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Apr 5 23:44:05 2023 +0800
#
#     update 3.8.1
#
# commit 76b1c3f6a17d9de2d0c287b181d68b413a894077
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Apr 5 23:43:21 2023 +0800
#
#     update 3.8.1
#
# commit 2a6a34abbedd975957e33f3a145a0a5ef889f3f3
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Mar 21 17:50:09 2023 +0800
#
#     update 3.8.1
#
# commit 4c017128f67b41f29f22a66e61e4c8e413eaa5bb
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Mar 11 15:13:52 2023 +0800
#
#     update 3.8.1
#
# commit 4a110e97e6f792180f4c8e3c22a4e70d6146b437
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Mar 11 12:28:08 2023 +0800
#
#     update 3.8.1
#
# commit f1c841be09806690ecb052381b41b89266b40a9c
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Mar 10 21:34:38 2023 +0800
#
#     update 3.8.1
#
# commit 2713147e71b30ab9b0893af1f9989cfc335e1609
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Mar 10 20:28:35 2023 +0800
#
#     update 3.8.0
#
# commit 730fe835c917572c32f7be8e9d1eda0868c6492f
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Mar 10 20:27:56 2023 +0800
#
#     update 3.8.0
#
# commit 633957eb0049e39b9b8bf6c5ccc73496e226f678
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Mar 10 18:14:36 2023 +0800
#
#     update 3.8.0
#
# commit bb359e690761a509ff2abf3661bae2d5f7dc00c8
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Mar 10 16:48:41 2023 +0800
#
#     update 3.8.0
#
# commit 660fe8099d25297b8b00777a700dcbb905898466
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Mar 10 16:45:15 2023 +0800
#
#     update 3.8.0
#
# commit 27a887f21fd2e05adda354c6131207827143f31a
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Mar 10 16:26:11 2023 +0800
#
#     update 3.8.0
#
# commit a020c029f45e67ac70172660c06cae6b4b884504
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Mar 5 15:40:39 2023 +0800
#
#     update 3.8.0
#
# commit d59e42f4281abe83950698eeed356fd22379c929
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Mar 5 15:29:00 2023 +0800
#
#     update 3.8.0
#
# commit f754f9e6c5a212b8137a23ed3c554c3f72bcbdc1
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Mar 5 15:18:30 2023 +0800
#
#     update 3.8.0
#
# commit 96f5ff9f8282e10b08254968e2872f977c7785fc
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Mar 5 14:58:29 2023 +0800
#
#     update 3.8.0
#
# commit a78f2409bbe22762f9371c8e4c26cb28c07f29cd
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Mar 4 21:30:57 2023 +0800
#
#     3.8.0
#
# commit ffb9d886b7b73a44aed0a90637ae96719e62346f
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Feb 10 01:06:00 2023 +0800
#
#     3.7.2
#
# commit 157a459540cf263007c702ab50904123071f1f93
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Feb 10 00:34:24 2023 +0800
#
#     3.7.2
#
# commit 6e227503041a7fb4b4d3d14a040e9d2a45fa2899
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Feb 10 00:23:03 2023 +0800
#
#     3.7.2
#
# commit 12cb5c7adb8d876b48bf538388a3c60fec85be7a
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Feb 9 21:08:41 2023 +0800
#
#     3.7.2
#
# commit 3700f18f024c373a108d2c7ab7ccc97fdf61063a
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Feb 9 21:08:06 2023 +0800
#
#     3.7.2
#
# commit 7cdd1b80bffe86a5b0ccb665edb4a0d57d343f15
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Feb 9 20:44:20 2023 +0800
#
#     3.7.2
#
# commit 79ce0f51d3407242530bb4c4001199fe98fd81a1
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Feb 9 20:27:09 2023 +0800
#
#     3.7.2
#
# commit a7dbb07671e0e68747e23944e1af40bc2cc172fb
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Feb 9 20:03:13 2023 +0800
#
#     3.7.2
#
# commit 63604423bf4cb3c661d185e739025f3f17d3fa99
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Feb 9 19:58:16 2023 +0800
#
#     3.7.2
#
# commit b37a9b8d26d44b0efc5f144f3620395191ff6296
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Feb 7 14:54:31 2023 +0800
#
#     3.7.1
#
# commit 6d83c54b5feeffd1a32be546ad9b451f99b39707
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Jan 31 15:52:35 2023 +0800
#
#     3.7.0
#
# commit 6c5a6f8795a48ca81fa15a2aeac2a9d7f3f7be4c
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Jan 30 14:57:03 2023 +0800
#
#     3.6.0
#
# commit 67515e5fede9d2c3362221571f60c6eff42ee0e1
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Mon Jan 30 14:33:31 2023 +0800
#
#     3.5.0
#
# commit 84b36c986d243a0ddbc13e089cc4d49a79814c54
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jan 28 20:07:55 2023 +0800
#
#     3.4.0
#
# commit 12e8c972637bd97056844ee4b593afe56217c833
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Jan 20 11:45:55 2023 +0800
#
#     3.3.3
#
# commit f6b488d55b7fe596c16456c380bc6b6c991a09ea
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Nov 27 20:55:55 2022 +0800
#
#     3.3.0
#
# commit 58b590403f3b4954f56bf7e1d62b320374ff7d95
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Nov 20 21:42:20 2022 +0800
#
#     3.3.0
#
# commit e10d9524c612425b5ab611c76413d3eac348cd9a
# Author: liangyun2 <liangyun2@tuhu.cn@macbook>
# Date:   Sun Nov 20 21:04:21 2022 +0800
#
#     revise
#
# commit b4ca8240901c64ca88e75864f000f5b9d0dcda42
# Author: liangyun2 <liangyun2@tuhu.cn@macbook>
# Date:   Sun Nov 20 21:01:25 2022 +0800
#
#     3.3.0
#
# commit 125bdc3707aebd6505e24c2de6bb85332e497c17
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Sep 16 11:45:45 2022 +0800
#
#     3.2.5
#
# commit 761d796906194359d14711bcdc123bba477c7680
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri Sep 16 11:28:04 2022 +0800
#
#     3.2.4
#
# commit 6cfa35bc1caab1c920f90b1580c70032d46645da
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jul 17 17:11:38 2022 +0800
#
#     3.2.3
#
# commit b8c01f58d348cda51966414b0ba28762663e8213
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jul 16 19:50:37 2022 +0800
#
#     3.2.2
#
# commit b185b02ff7adf1ae0c3b3ac71a10d0d3ef12cfdb
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jul 10 11:11:28 2022 +0800
#
#     3.2.0
#
# commit fd1e9fe9591b4e4fadc3f780d642470e7a4494cc
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jul 9 23:24:18 2022 +0800
#
#     3.1.0
#
# commit 933a71f8f909ac1f01db02ab6c2ca352086064d6
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jul 9 23:19:38 2022 +0800
#
#     3.1.0
#
# commit 0f2a536095b954daa8631887fbe78d81493f1ecf
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri May 27 12:40:39 2022 +0800
#
#     3.0.2
#
# commit 7db1c2009780b2d3cd75fd6df658acf1c3ae298b
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri May 27 10:41:09 2022 +0800
#
#     3.0.1
#
# commit 53a7bd32d9aa0dc5dd3f26b0f872f4b23f8124f9
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Fri May 27 10:06:35 2022 +0800
#
#     3.0.0
#
# commit 9d66849326ef196ebcbce254bd259fa4e34a1114
# Merge: 041398a 116fc02
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Feb 23 22:28:35 2021 +0800
#
#     Merge pull request #4 from laugh12321/master
#
#     Add EarltStopping and beautify the progressbar to make it more like keras.
#
# commit 116fc02a034f50239bff12d574b61b323da6cb8b
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Sat Feb 20 11:54:17 2021 +0800
#
#     2.2.1
#
# commit 8f3bb1ed07bd362e4549e8547bcf1f37fc7a89cd
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Sat Feb 20 11:33:12 2021 +0800
#
#     2.2.1
#
# commit 0aca17710f7e4b49ab8f62e0b7664c18ca27b509
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Thu Feb 18 23:03:38 2021 +0800
#
#     Live Update ProgressBar
#
# commit 5d635f387c0f578436ea7d13700c16daed2d19ed
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Thu Feb 18 21:44:57 2021 +0800
#
#     evaluation metrics
#
#     multiple evaluation metrics can be added
#
# commit 56b51cdc2f8c855752073325e951a764bdf6ea92
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Thu Feb 18 12:09:11 2021 +0800
#
#     Update README.md
#
# commit 1837db0501b9917521369d0167313e9fa9a80a13
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Thu Feb 18 12:08:58 2021 +0800
#
#     Delete Use_example.ipynb
#
# commit 1d6b60cea1e72c6113211dc1babffd8571e25ae5
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Thu Feb 18 12:05:12 2021 +0800
#
#     Create Use_example.ipynb
#
# commit 2af374517976401e0ddee70fa0b18c5056b20dd7
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Thu Feb 18 11:24:28 2021 +0800
#
#     Update README.md
#
# commit ecd10495b2534394d33de5da6ef8155bb849fbcd
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Thu Feb 18 11:13:26 2021 +0800
#
#     Update .gitignore
#
# commit daf8208a89ebfe801a4dbafe58f30b87ae54af07
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Thu Feb 18 11:13:18 2021 +0800
#
#     add EarlyStopping and beautify the progressbar
#
#     torchtools.py Source code copy from
#      Bjarten/early-stopping-pytorch;
#
#     utils.py Source code copy from
#      henryre/pytorch-fitmodule.
#
# commit 8b20d28cc33fe8c70fe246831ac20f69a33028b6
# Author: Laugh <laugh12321@vip.qq.com>
# Date:   Thu Feb 18 11:09:30 2021 +0800
#
#     delete __pycache__
#
# commit 041398aca1be519d65fc6b49924e0a7c755ec832
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jan 16 21:21:53 2021 +0800
#
#     2.1.2
#
# commit dd498c81988cc8de363d1eacc3f8851c313c8c94
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jan 16 16:34:25 2021 +0800
#
#     2.1.1
#
# commit 95970a048b0485eda2eb79946367349c4fac3176
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jan 16 16:30:41 2021 +0800
#
#     2.1.1
#
# commit 427b38be17f104e37b52d97a8f99eaeea6586bc4
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jan 16 16:27:57 2021 +0800
#
#     2.1.1
#
# commit 12a2bb97192af7126d2aa2a49b95ff61850aa52a
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sat Jan 16 16:21:39 2021 +0800
#
#     2.1.0
#
# commit e2c6373e50223d4b04a7611039e114297ab5516f
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Jul 16 23:19:15 2020 +0800
#
#     1.5.3
#
# commit af01f67ec035f1c67deb5294bd01fcbeefb25f3d
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Thu Jul 16 23:06:49 2020 +0800
#
#     1.5.2
#
# commit a5a5e4bc881b84aca60e9930fd70e9229d808412
# Merge: b34c421 d1802a6
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jul 5 08:21:57 2020 +0800
#
#     Merge branch 'master' of https://github.com/lyhue1991/torchkeras
#
# commit b34c421b9931f1c01c15320f9a9c27a9a684d547
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jul 5 08:21:22 2020 +0800
#
#     1.5.1
#
# commit 4ee567bd971cc20938cfc5e9012d98f92c474e24
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jul 5 08:13:31 2020 +0800
#
#     add torchkeras
#
# commit d1802a6d3adca47a09f5c1b57c079c50b649d0f6
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Jun 30 16:24:35 2020 +0800
#
#     Delete torchkeras.cpython-37.pyc
#
# commit 538e7f4be00ec1d73b012bc315fdd051dcf48def
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Jun 30 16:24:27 2020 +0800
#
#     Delete __init__.cpython-37.pyc
#
# commit e528745fa0b4a6b24b911994af7dff70b8b64e71
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Tue Jun 30 16:23:32 2020 +0800
#
#     revise readme
#
# commit 5502427f24eabeca76d42776d6f68d611b8ace85
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Jun 24 09:40:10 2020 +0800
#
#     fix a bug
#
# commit 68919c1a6525abec69815624e0361a377eb7a672
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Jun 24 09:26:18 2020 +0800
#
#     revise readme
#
# commit 1990aa54c07f0d6b7c893360d49430ceff08967a
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Jun 24 09:17:25 2020 +0800
#
#     revise readme
#
# commit 1d419d77feea6c29d179759013c2be95399ff7b9
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Jun 24 09:12:05 2020 +0800
#
#     consider cuda
#
# commit a691e058735e3f775442ff7b972315c7e8dae459
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Jun 24 00:33:23 2020 +0800
#
#     1.1
#
# commit 8eed2c64029bd2fceef8841283ceb07728c4f895
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Wed Jun 24 00:28:39 2020 +0800
#
#     consider training with gpu
#
# commit da4afed59281d79001cb2a6af57fbb4024d6024c
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jun 21 21:43:05 2020 +0800
#
#     revise LICENSE
#
# commit 3ae9c94b071b451c7e0748fe6eb3847049ae3875
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jun 21 21:40:20 2020 +0800
#
#     revise readme
#
# commit bd55ec4c53d1d693d1fdcb9db607557b564e2fee
# Author: lyhue1991 <lyhue1991@163.com>
# Date:   Sun Jun 21 21:28:17 2020 +0800
#
#     init commit

# %%
# !git commit -m"update 3.9.2"
# Out:
# [master d1277da] update 3.9.2
#  2 files changed, 12 insertions(+), 6 deletions(-)

# %%
#!git config pull.rebase true

# %%
#!git reset e8e99f652f4dd

# %%
#!git pull origin master
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), 57.25 KiB | 496.00 KiB/s, done.
# From github.com:lyhue1991/torchkeras
#  * branch            master     -> FETCH_HEAD
#    0c0c8bd..9dbbb45  master     -> origin/master
# Updating 0c0c8bd..9dbbb45
# Fast-forward
#  ...\250\213 - More-Annotation&Colab-Support.ipynb" | 5804 ++++++++++++++++++++
#  1 file changed, 5804 insertions(+)
#  create mode 100644 "examples/ChatGLM2-6b\345\276\256\350\260\203\344\277\235\345\247\206\347\272\247\346\225\231\347\250\213 - More-Annotation&Colab-Support.ipynb"

# %%
# !git remote remove origin

# %%
# !git remote add origin git@github.com:lyhue1991/torchkeras.git

# %%
# !git push  origin master
# Out:
# Enumerating objects: 43, done.
# Counting objects: 100% (43/43), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (30/30), done.
# Writing objects: 100% (32/32), 43.89 KiB | 2.74 MiB/s, done.
# Total 32 (delta 16), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (16/16), completed with 10 local objects.
# To github.com:lyhue1991/torchkeras.git
#    9dbbb45..d1277da  master -> master

# %%
# !git remote add gitee https://gitee.com/Python_Ai_Road/torchkeras

# %%
# !git push gitee master
# Out:
# Enumerating objects: 48, done.
# Counting objects: 100% (48/48), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (35/35), done.
# Writing objects: 100% (37/37), 101.10 KiB | 7.22 MiB/s, done.
# Total 37 (delta 18), reused 0 (delta 0), pack-reused 0
# remote: Powered by GITEE.COM [GNK-6.4]
# To https://gitee.com/Python_Ai_Road/torchkeras
#    0c0c8bd..d1277da  master -> master

# %%
#!git reset 462caeb349d

# %% [markdown]
# ## gitignore

# %%
# %%writefile .gitignore
# .DS_store
# .ipynb_checkpoints
# .ipynb_checkpoints/*
# torchkeras.egg-info/*
# dist/*
# build/*
# torchkeras/__pycache__/
# torchkeras/models/__pycache__/
# examples/datasets/
# examples/*.pt
# examples/wandb/
# torchkeras/ocr/__pycache__/
# torchkeras/chat/__pycache__/
# torchkeras/tools/__pycache__/
# examples/.ipynb_checkpoints
# examples/__pycache__/
# torchkeras/chatgpt/__pycache__/
# .idea
# mnist
# output_dir
# wandb
# *.pt
# debug.ipynb
# cats
# ImageCleaner
